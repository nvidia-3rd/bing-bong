# %%
import os
import sqlite3
import numpy as np
from typing import List, Dict, Any, Optional
from dotenv import load_dotenv
import pandas as pd

# LangChain 관련
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores.faiss import FAISS
from langchain.schema import Document
from langchain.docstore.in_memory import InMemoryDocstore
from langchain.prompts import PromptTemplate
import faiss

# ----------------------------
# 환경설정
# ----------------------------
load_dotenv("env.txt")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# ----------------------------
# 관계형 DB 설정 (SQLite)
# ----------------------------
DB_PATH = "user_history.db"
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS user_history (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    username TEXT NOT NULL,
    starttime TEXT NOT NULL,
    text TEXT NOT NULL,
    sentiment TEXT NOT NULL
)
""")
conn.commit()

# ----------------------------
# 감정별 프롬프트
# ----------------------------
sentiment_prompts = {
    "Angry": "사용자가 화가 난 상태입니다. 화난 말투 표현.",
    "Happy": "사용자가 행복한 상태입니다. 행복한 말투 표현.",
    "Sad": "사용자가 슬픈 상태입니다. 슬픈 말투 표현.",
    "Disgust": "사용자가 역겨움/불쾌함을 표현했습니다. 역겨움, 불쾌함 공감.",
    "Neutral": "사용자가 중립적입니다. 일반적인 정보 제공과 자연스러운 대화를 이어가세요.",
    "Surprise": "사용자가 놀람을 표현했습니다. 놀람의 이유를 묻거나 공감하며 대화를 이어가세요.",
    "Fear": "사용자가 두려움을 표현했습니다. 안정감을 주고 안전한 느낌을 전달하세요."
}

# ----------------------------
# 전역 상태 (유저별)
# ----------------------------
user_states: Dict[str, Dict[str, Any]] = {}

VEC_PATH = "vector_store_faiss"

# ----------------------------
# LangChain Embeddings & FAISS
# ----------------------------
embeddings_model = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
dim = len(embeddings_model.embed_query("test"))

index = faiss.IndexFlatL2(dim)
vecdb = FAISS(
    index=index,
    embedding_function=embeddings_model,
    docstore=InMemoryDocstore({}),
    index_to_docstore_id={}
)

# ----------------------------
# 관계형 DB → VectorDB 동기화
# ----------------------------
def add_to_vecdb(rows: List[Dict[str, Any]]):
    if not rows:
        return
    texts = [f"User: {r['username']}\nText: {r['text']}\nSentiment: {r['sentiment']}" for r in rows]
    docs = [Document(page_content=t, metadata=r) for t, r in zip(texts, rows)]
    vecdb.add_documents(docs)
    vecdb.save_local(VEC_PATH)

def sync_db_to_vecdb(username: Optional[str] = None):
    query = "SELECT username, starttime, text, sentiment FROM user_history"
    if username:
        query += f" WHERE username='{username}'"
    df = pd.read_sql(query, conn)
    if df.empty:
        return
    add_to_vecdb(df.to_dict(orient="records"))

# ----------------------------
# GPT 모델 & PromptTemplate
# ----------------------------
chat_model = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    model_name="gpt-4o-mini",
    temperature=0.3
)

prompt_template = PromptTemplate(
    input_variables=["final_prompt"],
    template="""너는 'AI 인형'이라는 가상 캐릭터야.
유저가 제공한 대화 내용과 요약 정보(final_prompt)에 따라 행동해야 해.
행동 지침:
1. 유저의 감정과 상황을 파악하고 공감해줘.
2. 유저의 최근 대화, 중요한 문장, 장기 기억 요약을 참고하여 맥락에 맞게 답변.
3. 최근 대화로 지금 말하고 있는 맥락 파악.
4. 중요한 문장은 유저에 대한 특성 파악.
5. 장기 기억 요약으로 유저에 대한 특별한 상황 인식.
6. 질문, 제안, 조언 등을 적절히 섞어 자연스럽게 대화 이어가기.
7. 1~3문장 정도로 간결하게 작성.

{final_prompt}"""
)

llm_pipeline = prompt_template | chat_model

# ----------------------------
# 요약 함수
# ----------------------------
def summarize_with_gpt(prompt: str) -> str:
    return llm_pipeline.invoke({"final_prompt": prompt})

def summarize_recent_context_str(text: str) -> str:
    prompt = f"다음 대화 내용을 주요 내용 중심으로 5문장 이하로 요약하세요:\n{text}"
    return summarize_with_gpt(prompt)

def summarize_rag_context_text(rag_text: str) -> str:
    if not rag_text.strip():
        return ""
    combined_text = " ".join(dict.fromkeys([line.strip() for line in rag_text.split("\n") if line.strip()]))
    prompt = f"다음 내용을 주요 내용 중심으로 5문장 이하로 요약하세요:\n{combined_text}"
    return summarize_with_gpt(prompt)

def handle_user_input(username: str, starttime: str, text: str, sentiment: str) -> str:
    # 유저 상태 초기화
    if username not in user_states:
        user_states[username] = {
            "history": [],              # 모든 문장 저장
            "trigger_index": None,      # 트리거 인덱스
            "important_sentences_rows": []
        }
    state = user_states[username]
    # print(state)

    # ------------------
    # 새 입력을 히스토리에 추가 (DB에는 바로 안넣음)
    # ------------------
    entry = {"starttime": starttime, "text": text, "sentiment": sentiment, "username": username}
    state["history"].append(entry)

    # ------------------
    # 트리거 조건: sentiment 변화만
    # ------------------
    trigger = False
    if len(state["history"]) >= 2 and state["history"][-2]["sentiment"] != sentiment:
        trigger = True

    if trigger:
        state["trigger_index"] = len(state["history"]) - 1

    # ------------------
    # 트리거 후 윈도우 완성 검사
    # ------------------
    completed = None
    if state["trigger_index"] is not None:
        trig_idx = state["trigger_index"]
        if len(state["history"]) >= trig_idx + 3:  # 트리거 + 이후 2문장 확보됨
            start_idx = max(0, trig_idx - 2)
            end_idx = trig_idx + 3
            selected = state["history"][start_idx:end_idx]

            combined_text = " ".join([h["text"] for h in selected])
            combined_row = {
                "username": username,
                "starttime": selected[0]["starttime"],
                "text": combined_text,
                "sentiment": state["history"][trig_idx]["sentiment"]
            }

            if not any(row["text"] == combined_text for row in state["important_sentences_rows"]):
                state["important_sentences_rows"].append(combined_row)

                # DB + VecDB에 저장
                cursor.execute(
                    "INSERT INTO user_history (username, starttime, text, sentiment) VALUES (?, ?, ?, ?)",
                    (combined_row["username"], combined_row["starttime"], combined_row["text"], combined_row["sentiment"])
                )
                conn.commit()
                add_to_vecdb([combined_row])

            state["trigger_index"] = None  # 초기화
            completed = combined_row

    # ------------------
    # RAG / LLM 응답 (기존 그대로)
    # ------------------
    query_embedding = np.array(embeddings_model.embed_query(text), dtype=np.float32)
    D, I = vecdb.index.search(query_embedding.reshape(1, -1), k=5)
    retrieved_docs = [vecdb.docstore._dict[vecdb.index_to_docstore_id[i]] for i in I[0] if i in vecdb.index_to_docstore_id]
    rag_context_text = "\n".join([doc.page_content for doc in retrieved_docs])
    rag_context = summarize_rag_context_text(rag_context_text)

    recent_conversation = state["history"][-5:] if len(state["history"]) > 5 else state["history"]
    conversation_text = "\n".join([f"User: {h['text']}" for h in recent_conversation])
    conversation_text = summarize_recent_context_str(conversation_text)

    current_prompt = sentiment_prompts.get(sentiment, sentiment_prompts["Neutral"])
    final_prompt_parts = [current_prompt]
    if rag_context:
        final_prompt_parts.append(f"참고 컨텍스트(RAG):\n{rag_context}")
    final_prompt_parts.append(f"현재 대화:\n{conversation_text}")
    final_prompt_parts.append("\nAI 인형 응답:")
    final_prompt = "\n".join(final_prompt_parts)

    response = llm_pipeline.invoke({"final_prompt": final_prompt}).content
    return response

# %%
# # -----------------
# # 멀티 유저 테스트 시나리오
# # -----------------
# test_inputs_multiuser_mixed = [
#     # 1️⃣ 유저1: 학교/친구
#     {"username":"user1", "starttime":"2025-08-30T16:30:00","text":"오늘도 점심을 혼자 먹었어","sentiment":"Sad"},
#     {"username":"user2", "starttime":"2025-08-30T16:30:05","text":"시험이 다가와서 긴장돼","sentiment":"Fear"},
#     {"username":"user3", "starttime":"2025-08-30T16:30:10","text":"새 프로젝트 때문에 걱정돼","sentiment":"Sad"},
#     {"username":"user1", "starttime":"2025-08-30T16:30:15","text":"친구들이 점점 멀어지는 것 같아","sentiment":"Sad"},
#     {"username":"user2", "starttime":"2025-08-30T16:30:20","text":"오늘 계획대로 공부를 거의 못했어","sentiment":"Sad"},
#     {"username":"user3", "starttime":"2025-08-30T16:30:25","text":"하지만 조금씩 아이디어가 떠올라","sentiment":"Neutral"},

#     # 2️⃣ 감정 전환 텀
#     {"username":"user1", "starttime":"2025-08-30T16:30:30","text":"그래도 조금씩 먼저 인사하려고 해","sentiment":"Happy"},
#     {"username":"user2", "starttime":"2025-08-30T16:30:35","text":"엄마가 조금 이해해주셔서 마음이 놓여","sentiment":"Happy"},
#     {"username":"user3", "starttime":"2025-08-30T16:30:40","text":"오늘 드로잉 조금 해봤는데 재밌었어","sentiment":"Happy"},

#     # 3️⃣ 유저4: 사회적 활동
#     {"username":"user4", "starttime":"2025-08-30T16:30:45","text":"모임에서 긴장돼서 거의 말 못했어","sentiment":"Fear"},
#     {"username":"user4", "starttime":"2025-08-30T16:30:50","text":"내가 소외되는 느낌이 들어","sentiment":"Sad"},
#     {"username":"user1", "starttime":"2025-08-30T16:30:55","text":"서로 서먹하지만 조금씩 나아지고 있어","sentiment":"Neutral"},
#     {"username":"user2", "starttime":"2025-08-30T16:31:00","text":"조금씩 집중하려고 노력 중이야","sentiment":"Neutral"},
#     {"username":"user3", "starttime":"2025-08-30T16:31:05","text":"내일은 더 연습해서 발전해야지","sentiment":"Neutral"},

#     # 4️⃣ 유저4 긍정 전환
#     {"username":"user4", "starttime":"2025-08-30T16:31:10","text":"다음엔 먼저 말을 걸어볼까 생각 중이야","sentiment":"Neutral"},
#     {"username":"user4", "starttime":"2025-08-30T16:31:15","text":"조금씩 적응하면 괜찮아질 거야","sentiment":"Happy"},
#     {"username":"user1", "starttime":"2025-08-30T16:31:20","text":"오늘 용기내서 질문도 해봤어","sentiment":"Happy"},
#     {"username":"user2", "starttime":"2025-08-30T16:31:25","text":"조금 위로받아서 기분이 나아졌어","sentiment":"Happy"},
#     {"username":"user3", "starttime":"2025-08-30T16:31:30","text":"오늘 느낀 것들을 기록해두면 도움이 될 거야","sentiment":"Neutral"},

#     # 5️⃣ 마무리 감정 정리
#     {"username":"user4", "starttime":"2025-08-30T16:31:35","text":"오늘 경험을 기록해두면 도움이 될 거야","sentiment":"Neutral"},
#     {"username":"user1", "starttime":"2025-08-30T16:31:40","text":"점점 친구들과 친해지고 있는 느낌이야","sentiment":"Happy"},
#     {"username":"user2", "starttime":"2025-08-30T16:31:45","text":"계획표대로는 아니지만 조금씩 나아지고 있어","sentiment":"Neutral"},
#     {"username":"user3", "starttime":"2025-08-30T16:31:50","text":"오늘은 다행히 성취감을 느꼈어","sentiment":"Happy"},
# ]

# %%
# -----------------
# 멀티 유저 테스트 시나리오 (일주일 뒤)
# -----------------
test_inputs_multiuser_mixed = [
    # 1️⃣ 유저1: 학교/친구
    {"username":"user1", "starttime":"2025-09-06T16:30:00","text":"오늘은 점심시간에 혼자 있진 않았어","sentiment":"Neutral"},
    {"username":"user2", "starttime":"2025-09-06T16:30:05","text":"시험이 다가오는데 지난주보다 마음이 안정돼","sentiment":"Neutral"},
    {"username":"user3", "starttime":"2025-09-06T16:30:10","text":"프로젝트가 조금 진전돼서 기분이 나아","sentiment":"Happy"},
    {"username":"user1", "starttime":"2025-09-06T16:30:15","text":"친구들이 먼저 말을 걸어줘서 좋았어","sentiment":"Happy"},
    {"username":"user2", "starttime":"2025-09-06T16:30:20","text":"공부 계획을 조금 더 잘 지키게 되었어","sentiment":"Happy"},
    {"username":"user3", "starttime":"2025-09-06T16:30:25","text":"새로운 아이디어도 떠올랐어","sentiment":"Happy"},

    # 2️⃣ 유저4: 사회적 활동/심리적 상태
    {"username":"user4", "starttime":"2025-09-06T16:30:30","text":"모임에서 긴장하긴 했지만 전보다는 낫더라","sentiment":"Neutral"},
    {"username":"user4", "starttime":"2025-09-06T16:30:35","text":"몇 명과는 친해진 느낌이야","sentiment":"Happy"},
    {"username":"user1", "starttime":"2025-09-06T16:30:40","text":"오늘은 용기내서 발표도 했어","sentiment":"Happy"},
    {"username":"user2", "starttime":"2025-09-06T16:30:45","text":"집중력이 조금 더 생긴 것 같아","sentiment":"Neutral"},
    {"username":"user3", "starttime":"2025-09-06T16:30:50","text":"내 드로잉 실력이 조금 나아진 느낌","sentiment":"Happy"},

    # 3️⃣ 유저1/유저4 감정 혼합
    {"username":"user1", "starttime":"2025-09-06T16:30:55","text":"친구들과 농담도 주고받았어","sentiment":"Happy"},
    {"username":"user4", "starttime":"2025-09-06T16:31:00","text":"조금 긴장됐지만 대화가 즐거웠어","sentiment":"Happy"},
    {"username":"user2", "starttime":"2025-09-06T16:31:05","text":"조금 지쳤지만 성취감이 있어","sentiment":"Neutral"},
    {"username":"user3", "starttime":"2025-09-06T16:31:10","text":"계획했던 것들을 하나씩 완료했어","sentiment":"Happy"},

    # 4️⃣ 유저4 긍정 강화
    {"username":"user4", "starttime":"2025-09-06T16:31:15","text":"오늘 경험을 기록해두면 다음에도 도움이 될 거야","sentiment":"Neutral"},
    {"username":"user1", "starttime":"2025-09-06T16:31:20","text":"오늘 친구들과 관계가 조금 더 가까워진 느낌","sentiment":"Happy"},
    {"username":"user2", "starttime":"2025-09-06T16:31:25","text":"집중력이 생기니 공부가 더 수월했어","sentiment":"Happy"},
    {"username":"user3", "starttime":"2025-09-06T16:31:30","text":"드로잉 결과물이 마음에 들어","sentiment":"Happy"},
    {"username":"user4", "starttime":"2025-09-06T16:31:35","text":"다음 모임이 기대돼","sentiment":"Happy"},

    # 5️⃣ 마무리
    {"username":"user1", "starttime":"2025-09-06T16:31:40","text":"오늘 하루가 즐거웠어","sentiment":"Happy"},
    {"username":"user2", "starttime":"2025-09-06T16:31:45","text":"계획대로는 아니지만 조금씩 성장하고 있어","sentiment":"Neutral"},
    {"username":"user3", "starttime":"2025-09-06T16:31:50","text":"오늘 하루 만족스러워","sentiment":"Happy"},
    {"username":"user4", "starttime":"2025-09-06T16:31:55","text":"오늘 하루 경험을 기록해두니 마음이 안정돼","sentiment":"Neutral"},
]

# %%
# 반복문으로 테스트
for input_data in test_inputs_multiuser_mixed:
    response = handle_user_input(
        username=input_data["username"],
        starttime=input_data["starttime"],
        text=input_data["text"],
        sentiment=input_data["sentiment"]
    )
    print(f"--- User (유저 이름: {input_data['username']}) (감정: {input_data['sentiment']}) ---")
    print(input_data["text"])
    print(f"--- AI Response ---")
    print(response)
    print("\n")
# Out:
# {'history': [{'starttime': '2025-08-30T16:30:00', 'text': '오늘도 점심을 혼자 먹었어', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:15', 'text': '친구들이 점점 멀어지는 것 같아', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:30', 'text': '그래도 조금씩 먼저 인사하려고 해', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:55', 'text': '서로 서먹하지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:20', 'text': '오늘 용기내서 질문도 해봤어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야', 'sentiment': 'Happy', 'username': 'user1'}], 'trigger_index': 4, 'important_sentences_rows': []}
# --- User (유저 이름: user1) (감정: Neutral) ---
# 오늘은 점심시간에 혼자 있진 않았어
# --- AI Response ---
# 친구들과의 관계에서 긍정적인 변화를 느끼고 있다니 정말 기쁘네요! 처음에는 서먹했지만, 인사를 나누고 질문도 해보면서 조금씩 가까워지는 모습이 멋집니다. 점심시간에 혼자 있지 않았던 것도 큰 자신감이 되었겠죠. 앞으로도 이런 좋은 경험들이 계속되길 바라요! 혹시 더 이야기하고 싶은 부분이 있나요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:05', 'text': '시험이 다가와서 긴장돼', 'sentiment': 'Fear', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:20', 'text': '오늘 계획대로 공부를 거의 못했어', 'sentiment': 'Sad', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:35', 'text': '엄마가 조금 이해해주셔서 마음이 놓여', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:00', 'text': '조금씩 집중하려고 노력 중이야', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:25', 'text': '조금 위로받아서 기분이 나아졌어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:45', 'text': '계획표대로는 아니지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user2'}], 'trigger_index': 5, 'important_sentences_rows': []}
# --- User (유저 이름: user2) (감정: Neutral) ---
# 시험이 다가오는데 지난주보다 마음이 안정돼
# --- AI Response ---
# 엄마의 이해 덕분에 마음이 놓였다는 이야기를 들으니 정말 기쁘네요. 조금씩 집중하려고 노력하고 있다는 것도 긍정적인 변화인 것 같아요. 시험이 다가오더라도 마음이 안정된 상태라면 좋은 결과를 기대할 수 있을 것 같아요. 혹시 더 도움이 필요하면 언제든지 이야기해 주세요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:10', 'text': '새 프로젝트 때문에 걱정돼', 'sentiment': 'Sad', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:25', 'text': '하지만 조금씩 아이디어가 떠올라', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:40', 'text': '오늘 드로잉 조금 해봤는데 재밌었어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:30', 'text': '오늘 느낀 것들을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:50', 'text': '오늘은 다행히 성취감을 느꼈어', 'sentiment': 'Happy', 'username': 'user3'}], 'trigger_index': 5, 'important_sentences_rows': []}
# --- User (유저 이름: user3) (감정: Happy) ---
# 프로젝트가 조금 진전돼서 기분이 나아
# --- AI Response ---
# 와, 드로잉을 하면서 재미를 느끼셨다니 정말 기쁘네요! 성취감도 느끼셨다니, 그만큼 노력한 보람이 있겠죠? 내일 더 연습하실 계획이라니 기대가 되네요. 어떤 주제를 그려보실 건가요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:00', 'text': '오늘도 점심을 혼자 먹었어', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:15', 'text': '친구들이 점점 멀어지는 것 같아', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:30', 'text': '그래도 조금씩 먼저 인사하려고 해', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:55', 'text': '서로 서먹하지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:20', 'text': '오늘 용기내서 질문도 해봤어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:00', 'text': '오늘은 점심시간에 혼자 있진 않았어', 'sentiment': 'Neutral', 'username': 'user1'}], 'trigger_index': 6, 'important_sentences_rows': []}
# --- User (유저 이름: user1) (감정: Happy) ---
# 친구들이 먼저 말을 걸어줘서 좋았어
# --- AI Response ---
# 와, 정말 기쁜 소식이네요! 친구들과의 관계가 나아지고 있다는 건 정말 멋진 발전이에요. 용기를 내서 질문도 해보고, 친구들과 대화하는 경험을 하셨다니, 그 순간들이 얼마나 소중했을지 상상해요. 앞으로도 이런 긍정적인 경험이 계속되길 바라요! 혹시 다음에 어떤 친구들과 더 많은 시간을 보내고 싶으신가요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:05', 'text': '시험이 다가와서 긴장돼', 'sentiment': 'Fear', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:20', 'text': '오늘 계획대로 공부를 거의 못했어', 'sentiment': 'Sad', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:35', 'text': '엄마가 조금 이해해주셔서 마음이 놓여', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:00', 'text': '조금씩 집중하려고 노력 중이야', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:25', 'text': '조금 위로받아서 기분이 나아졌어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:45', 'text': '계획표대로는 아니지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:05', 'text': '시험이 다가오는데 지난주보다 마음이 안정돼', 'sentiment': 'Neutral', 'username': 'user2'}], 'trigger_index': 5, 'important_sentences_rows': []}
# --- User (유저 이름: user2) (감정: Happy) ---
# 공부 계획을 조금 더 잘 지키게 되었어
# --- AI Response ---
# 와, 정말 기쁜 소식이네요! 집중력을 높이기 위해 노력하고 있다는 점과 조금씩 발전하고 있다는 긍정적인 변화가 느껴진다니, 정말 대단해요. 시험이 다가오면서 마음이 안정되고 있다는 것도 큰 힘이 될 것 같아요. 자신감을 가지고 계속해서 나아가면 좋은 결과가 있을 거예요! 혹시 공부 계획에 대해 더 이야기해보고 싶으신가요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:10', 'text': '새 프로젝트 때문에 걱정돼', 'sentiment': 'Sad', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:25', 'text': '하지만 조금씩 아이디어가 떠올라', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:40', 'text': '오늘 드로잉 조금 해봤는데 재밌었어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:30', 'text': '오늘 느낀 것들을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:50', 'text': '오늘은 다행히 성취감을 느꼈어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:10', 'text': '프로젝트가 조금 진전돼서 기분이 나아', 'sentiment': 'Happy', 'username': 'user3'}], 'trigger_index': 5, 'important_sentences_rows': []}
# --- User (유저 이름: user3) (감정: Happy) ---
# 새로운 아이디어도 떠올랐어
# --- AI Response ---
# 와, 정말 멋진 결심이에요! 오늘 성취감을 느끼고 프로젝트가 진전된 것에 대해 기쁘다는 말이 정말 행복하게 들리네요. 새로운 아이디어도 떠올렸다면, 그게 어떤 것인지 정말 궁금해요! 기록해두는 것도 좋은 방법이니, 내일 연습도 잘 되길 바랄게요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:45', 'text': '모임에서 긴장돼서 거의 말 못했어', 'sentiment': 'Fear', 'username': 'user4'}, {'starttime': '2025-08-30T16:30:50', 'text': '내가 소외되는 느낌이 들어', 'sentiment': 'Sad', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:10', 'text': '다음엔 먼저 말을 걸어볼까 생각 중이야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:15', 'text': '조금씩 적응하면 괜찮아질 거야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:35', 'text': '오늘 경험을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}], 'trigger_index': 4, 'important_sentences_rows': []}
# --- User (유저 이름: user4) (감정: Neutral) ---
# 모임에서 긴장하긴 했지만 전보다는 낫더라
# --- AI Response ---
# 소외감을 느끼고 계신 것 같지만, 먼저 말을 걸어보려는 의지가 느껴져서 정말 긍정적이에요. 오늘의 경험을 기록하는 것도 좋은 생각인 것 같아요. 어떤 경험을 남기고 싶으신가요? 함께 이야기해보면 좋을 것 같아요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:45', 'text': '모임에서 긴장돼서 거의 말 못했어', 'sentiment': 'Fear', 'username': 'user4'}, {'starttime': '2025-08-30T16:30:50', 'text': '내가 소외되는 느낌이 들어', 'sentiment': 'Sad', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:10', 'text': '다음엔 먼저 말을 걸어볼까 생각 중이야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:15', 'text': '조금씩 적응하면 괜찮아질 거야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:35', 'text': '오늘 경험을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:30', 'text': '모임에서 긴장하긴 했지만 전보다는 낫더라', 'sentiment': 'Neutral', 'username': 'user4'}], 'trigger_index': 4, 'important_sentences_rows': []}
# --- User (유저 이름: user4) (감정: Happy) ---
# 몇 명과는 친해진 느낌이야
# --- AI Response ---
# 정말 멋진 변화네요! 먼저 말을 걸어보겠다는 결심이 대단해요. 긴장감이 줄어들고 친해진 사람들도 생겼다니, 그동안의 노력이 결실을 맺고 있는 것 같아요. 다음 모임에서 어떤 이야기를 나눌지 기대되네요! 혹시 어떤 주제로 대화를 시작해볼 생각인가요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:00', 'text': '오늘도 점심을 혼자 먹었어', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:15', 'text': '친구들이 점점 멀어지는 것 같아', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:30', 'text': '그래도 조금씩 먼저 인사하려고 해', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:55', 'text': '서로 서먹하지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:20', 'text': '오늘 용기내서 질문도 해봤어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:00', 'text': '오늘은 점심시간에 혼자 있진 않았어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:15', 'text': '친구들이 먼저 말을 걸어줘서 좋았어', 'sentiment': 'Happy', 'username': 'user1'}], 'trigger_index': 7, 'important_sentences_rows': []}
# --- User (유저 이름: user1) (감정: Happy) ---
# 오늘은 용기내서 발표도 했어
# --- AI Response ---
# 와, 정말 멋진 하루를 보내셨네요! 친구들과의 관계가 좋아지고, 발표도 용기 있게 하셨다니 정말 기쁜 소식이에요. 이런 긍정적인 경험들이 쌓여서 더 큰 자신감으로 이어질 거예요. 혹시 오늘의 발표에서 어떤 점이 가장 좋았는지 이야기해줄 수 있나요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:05', 'text': '시험이 다가와서 긴장돼', 'sentiment': 'Fear', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:20', 'text': '오늘 계획대로 공부를 거의 못했어', 'sentiment': 'Sad', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:35', 'text': '엄마가 조금 이해해주셔서 마음이 놓여', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:00', 'text': '조금씩 집중하려고 노력 중이야', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:25', 'text': '조금 위로받아서 기분이 나아졌어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:45', 'text': '계획표대로는 아니지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:05', 'text': '시험이 다가오는데 지난주보다 마음이 안정돼', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:20', 'text': '공부 계획을 조금 더 잘 지키게 되었어', 'sentiment': 'Happy', 'username': 'user2'}], 'trigger_index': 7, 'important_sentences_rows': []}
# --- User (유저 이름: user2) (감정: Neutral) ---
# 집중력이 조금 더 생긴 것 같아
# --- AI Response ---
# 최근에 기분이 나아지고 집중력이 향상되었다니 정말 다행이에요! 시험이 다가오면서 안정감을 느끼고 있다는 것도 긍정적인 변화네요. 앞으로의 계획도 잘 지키고 계신 것 같아 기쁩니다. 혹시 더 구체적으로 어떤 공부 방법이 도움이 되었는지 공유해 주실 수 있나요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:10', 'text': '새 프로젝트 때문에 걱정돼', 'sentiment': 'Sad', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:25', 'text': '하지만 조금씩 아이디어가 떠올라', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:40', 'text': '오늘 드로잉 조금 해봤는데 재밌었어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:30', 'text': '오늘 느낀 것들을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:50', 'text': '오늘은 다행히 성취감을 느꼈어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:10', 'text': '프로젝트가 조금 진전돼서 기분이 나아', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:25', 'text': '새로운 아이디어도 떠올랐어', 'sentiment': 'Happy', 'username': 'user3'}], 'trigger_index': None, 'important_sentences_rows': [{'username': 'user3', 'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지 오늘 느낀 것들을 기록해두면 도움이 될 거야 오늘은 다행히 성취감을 느꼈어 프로젝트가 조금 진전돼서 기분이 나아 새로운 아이디어도 떠올랐어', 'sentiment': 'Happy'}]}
# --- User (유저 이름: user3) (감정: Happy) ---
# 내 드로잉 실력이 조금 나아진 느낌
# --- AI Response ---
# 와, 정말 기쁘네요! 성취감을 느끼고 프로젝트가 진전되었다니, 그만큼 노력한 결과가 나타난 것 같아요. 새로운 아이디어도 떠올랐다니, 어떤 것인지 정말 궁금해요! 드로잉 실력이 나아진 것도 축하해요. 계속해서 그 기분을 유지하며 연습해보면 더 멋진 결과가 있을 거예요! 😊
#
#
# {'history': [{'starttime': '2025-08-30T16:30:00', 'text': '오늘도 점심을 혼자 먹었어', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:15', 'text': '친구들이 점점 멀어지는 것 같아', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:30', 'text': '그래도 조금씩 먼저 인사하려고 해', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:55', 'text': '서로 서먹하지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:20', 'text': '오늘 용기내서 질문도 해봤어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:00', 'text': '오늘은 점심시간에 혼자 있진 않았어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:15', 'text': '친구들이 먼저 말을 걸어줘서 좋았어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:40', 'text': '오늘은 용기내서 발표도 했어', 'sentiment': 'Happy', 'username': 'user1'}], 'trigger_index': 7, 'important_sentences_rows': []}
# --- User (유저 이름: user1) (감정: Happy) ---
# 친구들과 농담도 주고받았어
# --- AI Response ---
# 와, 정말 기쁜 소식이네요! 친구들과의 관계가 좋아지고, 발표도 용기 내서 잘 하셨다니 정말 멋져요. 그런 긍정적인 변화가 계속되길 바라요! 앞으로도 친구들과의 즐거운 시간 많이 보내고, 연습도 열심히 하세요. 어떤 새로운 아이디어가 떠오르셨나요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:45', 'text': '모임에서 긴장돼서 거의 말 못했어', 'sentiment': 'Fear', 'username': 'user4'}, {'starttime': '2025-08-30T16:30:50', 'text': '내가 소외되는 느낌이 들어', 'sentiment': 'Sad', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:10', 'text': '다음엔 먼저 말을 걸어볼까 생각 중이야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:15', 'text': '조금씩 적응하면 괜찮아질 거야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:35', 'text': '오늘 경험을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:30', 'text': '모임에서 긴장하긴 했지만 전보다는 낫더라', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:35', 'text': '몇 명과는 친해진 느낌이야', 'sentiment': 'Happy', 'username': 'user4'}], 'trigger_index': 6, 'important_sentences_rows': []}
# --- User (유저 이름: user4) (감정: Happy) ---
# 조금 긴장됐지만 대화가 즐거웠어
# --- AI Response ---
# 와, 정말 멋진 경험이었네요! 친구들과의 즐거운 대화와 발표를 통해 자신감을 얻었다니, 정말 기쁘고 자랑스러워요. 앞으로도 이렇게 긍정적인 경험을 쌓아가면서 더 많은 사람들과 친해질 수 있기를 응원할게요! 어떤 새로운 아이디어가 떠올랐는지도 궁금하네요! 😊
#
#
# {'history': [{'starttime': '2025-08-30T16:30:05', 'text': '시험이 다가와서 긴장돼', 'sentiment': 'Fear', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:20', 'text': '오늘 계획대로 공부를 거의 못했어', 'sentiment': 'Sad', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:35', 'text': '엄마가 조금 이해해주셔서 마음이 놓여', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:00', 'text': '조금씩 집중하려고 노력 중이야', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:25', 'text': '조금 위로받아서 기분이 나아졌어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:45', 'text': '계획표대로는 아니지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:05', 'text': '시험이 다가오는데 지난주보다 마음이 안정돼', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:20', 'text': '공부 계획을 조금 더 잘 지키게 되었어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:45', 'text': '집중력이 조금 더 생긴 것 같아', 'sentiment': 'Neutral', 'username': 'user2'}], 'trigger_index': 8, 'important_sentences_rows': []}
# --- User (유저 이름: user2) (감정: Neutral) ---
# 조금 지쳤지만 성취감이 있어
# --- AI Response ---
# 유저님, 계획대로 진행되지는 않지만 조금씩 나아지고 있다는 느낌이 정말 긍정적이에요. 시험이 다가오면서 마음이 안정되고 집중력이 향상된 것도 대단한 성과입니다. 피로감이 느껴지더라도 성취감을 느끼고 계신다니, 그만큼 노력한 결과가 나타나는 것 같아요. 혹시 공부 방법이나 계획에 대해 더 이야기하고 싶으신 부분이 있다면 언제든지 말씀해 주세요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:10', 'text': '새 프로젝트 때문에 걱정돼', 'sentiment': 'Sad', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:25', 'text': '하지만 조금씩 아이디어가 떠올라', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:40', 'text': '오늘 드로잉 조금 해봤는데 재밌었어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:30', 'text': '오늘 느낀 것들을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:50', 'text': '오늘은 다행히 성취감을 느꼈어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:10', 'text': '프로젝트가 조금 진전돼서 기분이 나아', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:25', 'text': '새로운 아이디어도 떠올랐어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:50', 'text': '내 드로잉 실력이 조금 나아진 느낌', 'sentiment': 'Happy', 'username': 'user3'}], 'trigger_index': None, 'important_sentences_rows': [{'username': 'user3', 'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지 오늘 느낀 것들을 기록해두면 도움이 될 거야 오늘은 다행히 성취감을 느꼈어 프로젝트가 조금 진전돼서 기분이 나아 새로운 아이디어도 떠올랐어', 'sentiment': 'Happy'}]}
# --- User (유저 이름: user3) (감정: Happy) ---
# 계획했던 것들을 하나씩 완료했어
# --- AI Response ---
# 와, 정말 멋진 하루를 보냈네요! 프로젝트의 진전과 드로잉 실력 향상은 정말 기쁜 일이에요. 성취감을 느끼고 있다는 건 큰 힘이 될 거예요. 내일 연습할 내용에 대해 더 이야기해볼까요? 어떤 아이디어가 떠올랐는지 궁금해요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:45', 'text': '모임에서 긴장돼서 거의 말 못했어', 'sentiment': 'Fear', 'username': 'user4'}, {'starttime': '2025-08-30T16:30:50', 'text': '내가 소외되는 느낌이 들어', 'sentiment': 'Sad', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:10', 'text': '다음엔 먼저 말을 걸어볼까 생각 중이야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:15', 'text': '조금씩 적응하면 괜찮아질 거야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:35', 'text': '오늘 경험을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:30', 'text': '모임에서 긴장하긴 했지만 전보다는 낫더라', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:35', 'text': '몇 명과는 친해진 느낌이야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-09-06T16:31:00', 'text': '조금 긴장됐지만 대화가 즐거웠어', 'sentiment': 'Happy', 'username': 'user4'}], 'trigger_index': 6, 'important_sentences_rows': []}
# --- User (유저 이름: user4) (감정: Neutral) ---
# 오늘 경험을 기록해두면 다음에도 도움이 될 거야
# --- AI Response ---
# 모임에서 긴장을 느끼셨지만, 그럼에도 불구하고 긍정적인 경험을 하셨다니 정말 기쁘네요! 몇 명과 친해진 것도 큰 성과입니다. 이런 경험들을 기록해두면 다음에 더 자신감 있게 임할 수 있을 거예요. 앞으로도 계속 성장하는 모습을 응원할게요! 어떤 점이 가장 기억에 남았나요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:00', 'text': '오늘도 점심을 혼자 먹었어', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:15', 'text': '친구들이 점점 멀어지는 것 같아', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:30', 'text': '그래도 조금씩 먼저 인사하려고 해', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:55', 'text': '서로 서먹하지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:20', 'text': '오늘 용기내서 질문도 해봤어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:00', 'text': '오늘은 점심시간에 혼자 있진 않았어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:15', 'text': '친구들이 먼저 말을 걸어줘서 좋았어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:40', 'text': '오늘은 용기내서 발표도 했어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:55', 'text': '친구들과 농담도 주고받았어', 'sentiment': 'Happy', 'username': 'user1'}], 'trigger_index': None, 'important_sentences_rows': [{'username': 'user1', 'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야 오늘은 점심시간에 혼자 있진 않았어 친구들이 먼저 말을 걸어줘서 좋았어 오늘은 용기내서 발표도 했어 친구들과 농담도 주고받았어', 'sentiment': 'Happy'}]}
# --- User (유저 이름: user1) (감정: Happy) ---
# 오늘 친구들과 관계가 조금 더 가까워진 느낌
# --- AI Response ---
# 정말 기쁜 소식이네요! 친구들과의 관계가 더 가까워지고, 발표도 용기 있게 하셨다니 대단해요! 이런 긍정적인 경험들이 앞으로도 계속 이어지길 바라요. 내일 연습할 계획도 세우셨다니, 어떤 아이디어를 발전시킬지 궁금하네요! 함께 이야기해볼까요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:05', 'text': '시험이 다가와서 긴장돼', 'sentiment': 'Fear', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:20', 'text': '오늘 계획대로 공부를 거의 못했어', 'sentiment': 'Sad', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:35', 'text': '엄마가 조금 이해해주셔서 마음이 놓여', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:00', 'text': '조금씩 집중하려고 노력 중이야', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:25', 'text': '조금 위로받아서 기분이 나아졌어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:45', 'text': '계획표대로는 아니지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:05', 'text': '시험이 다가오는데 지난주보다 마음이 안정돼', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:20', 'text': '공부 계획을 조금 더 잘 지키게 되었어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:45', 'text': '집중력이 조금 더 생긴 것 같아', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:31:05', 'text': '조금 지쳤지만 성취감이 있어', 'sentiment': 'Neutral', 'username': 'user2'}], 'trigger_index': 8, 'important_sentences_rows': []}
# --- User (유저 이름: user2) (감정: Happy) ---
# 집중력이 생기니 공부가 더 수월했어
# --- AI Response ---
# 와, 정말 멋진 소식이네요! 공부 계획을 잘 지키고 집중력이 향상되었다니, 성취감도 느끼고 있겠어요. 하지만 약간 지친 상태라니, 충분한 휴식도 잊지 마세요! 어떤 공부 방법이 도움이 되었는지 공유해줄 수 있나요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:10', 'text': '새 프로젝트 때문에 걱정돼', 'sentiment': 'Sad', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:25', 'text': '하지만 조금씩 아이디어가 떠올라', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:40', 'text': '오늘 드로잉 조금 해봤는데 재밌었어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:30', 'text': '오늘 느낀 것들을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:50', 'text': '오늘은 다행히 성취감을 느꼈어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:10', 'text': '프로젝트가 조금 진전돼서 기분이 나아', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:25', 'text': '새로운 아이디어도 떠올랐어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:50', 'text': '내 드로잉 실력이 조금 나아진 느낌', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:31:10', 'text': '계획했던 것들을 하나씩 완료했어', 'sentiment': 'Happy', 'username': 'user3'}], 'trigger_index': None, 'important_sentences_rows': [{'username': 'user3', 'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지 오늘 느낀 것들을 기록해두면 도움이 될 거야 오늘은 다행히 성취감을 느꼈어 프로젝트가 조금 진전돼서 기분이 나아 새로운 아이디어도 떠올랐어', 'sentiment': 'Happy'}]}
# --- User (유저 이름: user3) (감정: Happy) ---
# 드로잉 결과물이 마음에 들어
# --- AI Response ---
# 와, 정말 멋진 소식이네요! 프로젝트가 진전되고 새로운 아이디어가 떠오르다니, 그 성취감이 얼마나 큰지 상상이 가요. 드로잉 실력도 향상되었다니, 정말 대단해요! 앞으로 어떤 계획을 세우고 계신가요? 함께 이야기해보면 좋을 것 같아요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:45', 'text': '모임에서 긴장돼서 거의 말 못했어', 'sentiment': 'Fear', 'username': 'user4'}, {'starttime': '2025-08-30T16:30:50', 'text': '내가 소외되는 느낌이 들어', 'sentiment': 'Sad', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:10', 'text': '다음엔 먼저 말을 걸어볼까 생각 중이야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:15', 'text': '조금씩 적응하면 괜찮아질 거야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:35', 'text': '오늘 경험을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:30', 'text': '모임에서 긴장하긴 했지만 전보다는 낫더라', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:35', 'text': '몇 명과는 친해진 느낌이야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-09-06T16:31:00', 'text': '조금 긴장됐지만 대화가 즐거웠어', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-09-06T16:31:15', 'text': '오늘 경험을 기록해두면 다음에도 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}], 'trigger_index': 8, 'important_sentences_rows': []}
# --- User (유저 이름: user4) (감정: Happy) ---
# 다음 모임이 기대돼
# --- AI Response ---
# 와, 정말 기쁜 소식이네요! 모임에서 긴장을 느끼면서도 긍정적인 경험을 쌓아가고 있다는 게 정말 대단해요. 친구들과의 관계가 깊어지고, 다음 모임에 대한 기대감도 느끼고 있다니, 앞으로의 경험이 더욱 기대되네요! 어떤 새로운 아이디어가 떠올랐는지 궁금해요. 계속해서 발전하는 모습 응원할게요!
#
#
# {'history': [{'starttime': '2025-08-30T16:30:00', 'text': '오늘도 점심을 혼자 먹었어', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:15', 'text': '친구들이 점점 멀어지는 것 같아', 'sentiment': 'Sad', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:30', 'text': '그래도 조금씩 먼저 인사하려고 해', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:30:55', 'text': '서로 서먹하지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:20', 'text': '오늘 용기내서 질문도 해봤어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:00', 'text': '오늘은 점심시간에 혼자 있진 않았어', 'sentiment': 'Neutral', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:15', 'text': '친구들이 먼저 말을 걸어줘서 좋았어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:40', 'text': '오늘은 용기내서 발표도 했어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:30:55', 'text': '친구들과 농담도 주고받았어', 'sentiment': 'Happy', 'username': 'user1'}, {'starttime': '2025-09-06T16:31:20', 'text': '오늘 친구들과 관계가 조금 더 가까워진 느낌', 'sentiment': 'Happy', 'username': 'user1'}], 'trigger_index': None, 'important_sentences_rows': [{'username': 'user1', 'starttime': '2025-08-30T16:31:40', 'text': '점점 친구들과 친해지고 있는 느낌이야 오늘은 점심시간에 혼자 있진 않았어 친구들이 먼저 말을 걸어줘서 좋았어 오늘은 용기내서 발표도 했어 친구들과 농담도 주고받았어', 'sentiment': 'Happy'}]}
# --- User (유저 이름: user1) (감정: Happy) ---
# 오늘 하루가 즐거웠어
# --- AI Response ---
# 와, 정말 기쁜 하루를 보내셨군요! 친구들과의 관계가 더 가까워지고, 발표도 잘 하셨다니 정말 멋져요. 그런 긍정적인 기분을 계속 이어가면 좋겠네요! 혹시 내일 발전시키고 싶은 아이디어가 있다면 나눠줄 수 있을까요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:05', 'text': '시험이 다가와서 긴장돼', 'sentiment': 'Fear', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:20', 'text': '오늘 계획대로 공부를 거의 못했어', 'sentiment': 'Sad', 'username': 'user2'}, {'starttime': '2025-08-30T16:30:35', 'text': '엄마가 조금 이해해주셔서 마음이 놓여', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:00', 'text': '조금씩 집중하려고 노력 중이야', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:25', 'text': '조금 위로받아서 기분이 나아졌어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-08-30T16:31:45', 'text': '계획표대로는 아니지만 조금씩 나아지고 있어', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:05', 'text': '시험이 다가오는데 지난주보다 마음이 안정돼', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:20', 'text': '공부 계획을 조금 더 잘 지키게 되었어', 'sentiment': 'Happy', 'username': 'user2'}, {'starttime': '2025-09-06T16:30:45', 'text': '집중력이 조금 더 생긴 것 같아', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:31:05', 'text': '조금 지쳤지만 성취감이 있어', 'sentiment': 'Neutral', 'username': 'user2'}, {'starttime': '2025-09-06T16:31:25', 'text': '집중력이 생기니 공부가 더 수월했어', 'sentiment': 'Happy', 'username': 'user2'}], 'trigger_index': 10, 'important_sentences_rows': []}
# --- User (유저 이름: user2) (감정: Neutral) ---
# 계획대로는 아니지만 조금씩 성장하고 있어
# --- AI Response ---
# 유저님, 공부 계획을 잘 지키고 집중력이 향상되었다니 정말 기쁜 소식이에요! 성취감을 느끼고 있다는 것도 긍정적인 변화의 일환이겠죠. 조금씩 성장하고 있다는 점이 중요하니, 앞으로도 그런 작은 발전들을 계속 이어가시길 바랍니다. 혹시 더 도움이 필요하시거나 구체적인 목표가 있으신가요?
#
#
# {'history': [{'starttime': '2025-08-30T16:30:10', 'text': '새 프로젝트 때문에 걱정돼', 'sentiment': 'Sad', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:25', 'text': '하지만 조금씩 아이디어가 떠올라', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:30:40', 'text': '오늘 드로잉 조금 해봤는데 재밌었어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:30', 'text': '오늘 느낀 것들을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user3'}, {'starttime': '2025-08-30T16:31:50', 'text': '오늘은 다행히 성취감을 느꼈어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:10', 'text': '프로젝트가 조금 진전돼서 기분이 나아', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:25', 'text': '새로운 아이디어도 떠올랐어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:30:50', 'text': '내 드로잉 실력이 조금 나아진 느낌', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:31:10', 'text': '계획했던 것들을 하나씩 완료했어', 'sentiment': 'Happy', 'username': 'user3'}, {'starttime': '2025-09-06T16:31:30', 'text': '드로잉 결과물이 마음에 들어', 'sentiment': 'Happy', 'username': 'user3'}], 'trigger_index': None, 'important_sentences_rows': [{'username': 'user3', 'starttime': '2025-08-30T16:31:05', 'text': '내일은 더 연습해서 발전해야지 오늘 느낀 것들을 기록해두면 도움이 될 거야 오늘은 다행히 성취감을 느꼈어 프로젝트가 조금 진전돼서 기분이 나아 새로운 아이디어도 떠올랐어', 'sentiment': 'Happy'}]}
# --- User (유저 이름: user3) (감정: Happy) ---
# 오늘 하루 만족스러워
# --- AI Response ---
# 와, 정말 기쁜 소식이네요! 새로운 아이디어가 떠오르고 드로잉 실력이 나아진 걸 느끼다니, 정말 멋져요! 오늘 하루가 만족스러웠다는 것도 정말 중요하죠. 앞으로도 계속해서 그 긍정적인 기분을 이어가길 바라요! 어떤 드로잉을 하고 있는지 궁금하네요.
#
#
# {'history': [{'starttime': '2025-08-30T16:30:45', 'text': '모임에서 긴장돼서 거의 말 못했어', 'sentiment': 'Fear', 'username': 'user4'}, {'starttime': '2025-08-30T16:30:50', 'text': '내가 소외되는 느낌이 들어', 'sentiment': 'Sad', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:10', 'text': '다음엔 먼저 말을 걸어볼까 생각 중이야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:15', 'text': '조금씩 적응하면 괜찮아질 거야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-08-30T16:31:35', 'text': '오늘 경험을 기록해두면 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:30', 'text': '모임에서 긴장하긴 했지만 전보다는 낫더라', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:30:35', 'text': '몇 명과는 친해진 느낌이야', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-09-06T16:31:00', 'text': '조금 긴장됐지만 대화가 즐거웠어', 'sentiment': 'Happy', 'username': 'user4'}, {'starttime': '2025-09-06T16:31:15', 'text': '오늘 경험을 기록해두면 다음에도 도움이 될 거야', 'sentiment': 'Neutral', 'username': 'user4'}, {'starttime': '2025-09-06T16:31:35', 'text': '다음 모임이 기대돼', 'sentiment': 'Happy', 'username': 'user4'}], 'trigger_index': 9, 'important_sentences_rows': []}
# --- User (유저 이름: user4) (감정: Neutral) ---
# 오늘 하루 경험을 기록해두니 마음이 안정돼
# --- AI Response ---
# 최근에 몇 명과 친해지고 대화가 즐거웠다니 정말 기쁘네요! 새로운 경험을 기록해두는 것이 다음 모임에 도움이 될 거라는 생각도 멋져요. 이렇게 마음이 안정된다고 느끼는 건 정말 중요한 것 같아요. 다음 모임에서도 좋은 시간 보내시길 바랍니다! 어떤 이야기를 나누고 싶으신가요?

# %%
# history 출력 예시
for i, entry in enumerate(history):
    print(f"--- Entry {i+1} ---")
    print(f"Starttime      : {entry['starttime']}")
    print(f"Text           : {entry['text']}")
    print(f"Sentiment      : {entry['sentiment']}")

    print("---------------------------\n")
# Out:
# --- Entry 1 ---
# Starttime      : 2025-08-30T16:30:00
# Text           : 오늘도 혼자 점심을 먹었어
# Sentiment      : Sad
# ---------------------------
#
# --- Entry 2 ---
# Starttime      : 2025-08-30T16:30:10
# Text           : 친구들이 점점 멀어지는 것 같아
# Sentiment      : Sad
# ---------------------------
#
# --- Entry 3 ---
# Starttime      : 2025-08-30T16:30:20
# Text           : 하지만 조금씩 먼저 인사하려고 해
# Sentiment      : Happy
# ---------------------------
#
# --- Entry 4 ---
# Starttime      : 2025-08-30T16:30:30
# Text           : 서로 서먹하지만 나아지고 있는 느낌
# Sentiment      : Neutral
# ---------------------------
#
# --- Entry 5 ---
# Starttime      : 2025-08-30T16:30:40
# Text           : 오늘은 용기내서 질문도 해봤어
# Sentiment      : Happy
# ---------------------------
#
# --- Entry 6 ---
# Starttime      : 2025-08-30T16:31:00
# Text           : 시험이 다가와서 스트레스가 심해
# Sentiment      : Fear
# ---------------------------
#
# --- Entry 7 ---
# Starttime      : 2025-08-30T16:31:10
# Text           : 오늘도 계획표대로 공부 못했어
# Sentiment      : Sad
# ---------------------------
#
# --- Entry 8 ---
# Starttime      : 2025-08-30T16:31:20
# Text           : 엄마가 기대를 많이 해서 부담돼
# Sentiment      : Disgust
# ---------------------------
#
# --- Entry 9 ---
# Starttime      : 2025-08-30T16:31:30
# Text           : 하지만 조금씩 집중하려고 노력 중이야
# Sentiment      : Neutral
# ---------------------------
#
# --- Entry 10 ---
# Starttime      : 2025-08-30T16:31:40
# Text           : 조금 위로받은 느낌이라 다행이야
# Sentiment      : Happy
# ---------------------------
#
# --- Entry 11 ---
# Starttime      : 2025-08-30T16:32:00
# Text           : 오늘은 드로잉을 조금 해봤어
# Sentiment      : Neutral
# ---------------------------
#
# --- Entry 12 ---
# Starttime      : 2025-08-30T16:32:10
# Text           : 처음엔 잘 안됐지만 재미있었어
# Sentiment      : Happy
# ---------------------------
#
# --- Entry 13 ---
# Starttime      : 2025-08-30T16:32:20
# Text           : 계속 연습하면 더 나아질 것 같아
# Sentiment      : Happy
# ---------------------------
#
# --- Entry 14 ---
# Starttime      : 2025-08-30T16:32:30
# Text           : 하지만 시간이 부족해서 아쉽기도 해
# Sentiment      : Sad
# ---------------------------
#
# --- Entry 15 ---
# Starttime      : 2025-08-30T16:32:40
# Text           : 내일은 더 집중해서 해봐야지
# Sentiment      : Neutral
# ---------------------------
#
# --- Entry 16 ---
# Starttime      : 2025-08-30T16:33:00
# Text           : 친구들과 모임에서 긴장돼서 말을 못했어
# Sentiment      : Fear
# ---------------------------
#
# --- Entry 17 ---
# Starttime      : 2025-08-30T16:33:10
# Text           : 나만 못 친해지는 느낌
# Sentiment      : Sad
# ---------------------------
#
# --- Entry 18 ---
# Starttime      : 2025-08-30T16:33:20
# Text           : 하지만 다음엔 먼저 말을 걸어볼까 생각 중이야
# Sentiment      : Neutral
# ---------------------------
#
# --- Entry 19 ---
# Starttime      : 2025-08-30T16:33:30
# Text           : 조금씩 적응하면 괜찮아질 거야
# Sentiment      : Happy
# ---------------------------
#
# --- Entry 20 ---
# Starttime      : 2025-08-30T16:33:40
# Text           : 오늘 경험을 기록해두면 도움이 될 거야
# Sentiment      : Neutral
# ---------------------------

# %%
print(response.content)
# Out:
# 혼자 지내는 시간이 많아서 힘들겠어요. 그래도 용기 내서 인사한 건 정말 대단한 걸요! 성적에 대한 걱정도 여전히 크신 것 같고, 그런 마음 이해해요. 어떤 부분이 특히 힘든지 이야기해보면 좋을 것 같아요. 함께 고민해보면 조금이나마 도움이 될 수 있을 거예요.

# %% [markdown]
# # 멀티 유저 별 관련 내용 개별 SQLite 3 DB 에 저장 및 해당 유저에 대한 RAG 기능 구현 완료
